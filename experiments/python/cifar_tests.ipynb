# %%
from amm_main import main_cifar10, main_cifar100

METHOD = 'Mithral'

# %%
main_cifar10(METHOD)
# Out:
# running method:  Mithral
# got hparams:
# {'lut_work_const': 2, 'ncodebooks': 2}
# -------- running task: CIFAR-10 Softmax (1/12)
# ...
# learn_multisplits(): initial loss:    9364219.0
# learn_multisplits(): returning loss:  3137467.540710449
# ...
# learn_multisplits(): initial loss:    9407525.0
# learn_multisplits(): returning loss:  2967384.436454773
# X_res mse / X mse:  0.27701074
# X_res mse / X mse after lstsq:  0.108206585
# 3.87752
# A_enc: (10000, 2)
# B_enc: (512, 2, 16)
# Error(c != c_hat / total): 0.0016
# Memory: 65536
# got hparams:
# {'lut_work_const': 4, 'ncodebooks': 2}
# -------- running task: CIFAR-10 Softmax (1/12)
# hparams apparently invalid: lut_work_const > ncodebooks: 4 > 2
# got hparams:
# {'lut_work_const': -1, 'ncodebooks': 2}
# -------- running task: CIFAR-10 Softmax (1/12)
# X_res mse / X mse:  0.27701074
# fitting dense lstsq to X_res
# X_res mse / X mse after lstsq:  0.108206585
# 3.87752
# A_enc: (10000, 2)
# B_enc: (512, 2, 16)
# ...

# %%
main_cifar100(METHOD)
# Out:
# running method:  Mithral
# got hparams:
# {'lut_work_const': 2, 'ncodebooks': 2}
# -------- running task: CIFAR-100 Softmax (1/12)
# ...
# learn_multisplits(): initial loss:    12039954.0
# learn_multisplits(): returning loss:  9540616.578125
# ...
# learn_multisplits(): initial loss:    11932078.0
# learn_multisplits(): returning loss:  9437571.03125
# X_res mse / X mse:  0.74332696
# X_res mse / X mse after lstsq:  0.61440766
# 7.80345
# A_enc: (10000, 2)
# B_enc: (512, 2, 16)
# Error(c != c_hat / total): 0.0049
# Memory: 65536
# got hparams:
# {'lut_work_const': 4, 'ncodebooks': 2}
# -------- running task: CIFAR-100 Softmax (1/12)
# hparams apparently invalid: lut_work_const > ncodebooks: 4 > 2
# got hparams:
# {'lut_work_const': -1, 'ncodebooks': 2}
# -------- running task: CIFAR-100 Softmax (1/12)
# X_res mse / X mse:  0.74332696
# fitting dense lstsq to X_res
# X_res mse / X mse after lstsq:  0.61440766
# 7.80345
# A_enc: (10000, 2)
# B_enc: (512, 2, 16)
# ...
